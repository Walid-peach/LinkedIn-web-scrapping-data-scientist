# %%
import time

# %%
import os, random, sys, time

# %%
from urllib.parse import urlparse

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
#import requests

# %%
driver_path = "C:\Program Files (x86)\chromedriver.exe"
brave_path = "C:\Program Files\BraveSoftware\Brave-Browser\Application\Brave.exe"

option = webdriver.ChromeOptions()
option.binary_location = brave_path
# option.add_argument("--incognito") OPTIONAL
# option.add_argument("--headless") OPTIONAL

# Create new Instance of Chrome
browser = webdriver.Chrome(executable_path=driver_path, options=option)
baseurl='https://www.linkedin.com/'

# %%
def scrollpg(x):    
    SCROLL_PAUSE_TIME =x

    # Get scroll height
    last_height = browser.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom
        browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)

        # Calculate new scroll height and compare with last scroll height
        new_height = browser.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

# %%
browser.get('https://www.linkedin.com/login')

# %%
file = open('Sign in.txt')
lines = file.readlines()
username = lines[0]
passwd = lines[1]

# %%
elementID = browser.find_element_by_id('username')
elementID.send_keys(username)

# %%
elementID = browser.find_element_by_id('password')
elementID.send_keys(passwd)

# %%
elementID.submit()

# %%
for x in range(1,2):
    browser.get(f'https://www.linkedin.com/search/results/people/?keywords=data%20scientist&origin=SWITCH_SEARCH_VERTICAL&page={x}')

# %%
soup = BeautifulSoup(browser.page_source,'lxml')

# %%
reseachlist = soup.find_all('span',{'class':'entity-result__title-text t-16'})
reseachlist
# Out:
# []

# %%
reseachlinks = []
def my_function(x):
  return list(dict.fromkeys(x))

# %% [markdown]
# # search of profiles

# %%
reseachlinks = []
def my_function(x):
  return list(dict.fromkeys(x))

# %%
for x in range(1,25):
    
    browser.get(f'https://www.linkedin.com/search/results/people/?keywords=data%20scientist&origin=SWITCH_SEARCH_VERTICAL&page={x}')
    scrollpg(5)
    soup = BeautifulSoup(browser.page_source,'lxml')
    reseachlist = soup.find_all('span',{'class':'entity-result__title-text t-16'})
    for item in reseachlist :
        #print(item)
        for link in item.find_all('a',href=True):
            #print(link['href'])
            if len(link['href']) > 28:
                reseachlinks.append(link['href'])
                #print(link['href'])
reseachlinks = my_function(reseachlinks)
reseachlinks
# Out:
# ['https://www.linkedin.com/in/zaid-hammouch-b81872a2',
#  'https://www.linkedin.com/in/sarah-amar',
#  'https://www.linkedin.com/in/lamiaskalli',
#  'https://www.linkedin.com/in/fatima-ezzahra-banouj-00322257',
#  'https://www.linkedin.com/in/hanane-triy',
#  'https://www.linkedin.com/in/jannaniayoub',
#  'https://www.linkedin.com/in/hajar-falih-71661a3a',
#  'https://www.linkedin.com/in/siham-eddamiri-56b98aab',
#  'https://www.linkedin.com/in/oussama-kiassi',
#  'https://www.linkedin.com/in/khaoula-rabih',
#  'https://www.linkedin.com/in/azmi-mohamed-6051b91b',
#  'https://www.linkedin.com/in/oussama-maaizate-544b94160',
#  'https://www.linkedin.com/in/lamiaa-chahir-247b67172',
#  'https://www.linkedin.com/in/sd-t',
#  'https://www.linkedin.com/in/hamza-benjemra-36b848173',
#  'https://www.linkedin.com/in/hamza-kamil-57a87a140',
#  'https://www.linkedin.com/in/mehdi-el-haylali',
#  'https://www.linkedin.com/in/khouloud-tabiti-589948127',
# ...

# %%
len(reseachlinks)
# Out:
# 199

# %%
testlink ='https://www.linkedin.com/in/sarah-amar'
browser.get(testlink)

# %%
#driver.maximize_window()

#scroll by pixcel
browser.execute_script("window.scrollBy(0,1500)","")
time.sleep(4)
#browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
#time.sleep(1)

# %%
#sectionID = []
#scrollpg(5)
sourcepg = browser.page_source
soup = BeautifulSoup(sourcepg,'lxml')

# %%
name_div = soup.find('div',{'class':"flex-1 mr5 pv-top-card__list-container"})
#name_div

# %%
name = name_div.find('li',{'class':"inline t-24 t-black t-normal break-words"}).get_text().strip()
location = name_div.find('li',{'class':"t-16 t-black t-normal inline-block"}).get_text().strip()

location, name
# Out:
# ('Casablanca-Settat, Maroc', 'Sarah Amar')

# %%
exper_div= soup.find('div',{'class':"display-flex justify-space-between full-width"})
exper_h3= exper_div.find_all('a',href = True)
urltest = baseurl +exper_h3[0]['href']

# %%
browser.get("https://www.linkedin.com/company/ocp/")
scrollpg(2)
time.sleep(2)

# %%
soup1 = BeautifulSoup(browser.page_source,'html.parser')

# %%
name_comp
# Out:
# 'OCP SA'

# %%
try :
    name_div_com = soup1.find('div',{'class':'ph5 pt3'})
    name_comp = name_div_com.find('span').get_text().strip()
    effic_ancien_list =soup1.find_all('span',{'class':'t-24 v-align-middle'})
    leplus = soup1.find('span',{'class':'org-highlight-insights-module__rate-increase'})
    if leplus==None:
        effic = "-"+effic_ancien_list[0].get_text().strip().replace('\xa0','')
    else :
        effic = effic_ancien_list[0].get_text().strip().replace('\xa0','')
    ancient = effic_ancien_list[1].get_text().strip().replace('\xa0','')
    
    print(effic +"\n"+ancient +"\n"+name_comp)
except Exception :
    print('NaN')
# Out:
# 3%
# 5,9ans
# OCP SA

# %%
browser.get("https://www.linkedin.com/company/ocp/")
scrollpg(2)
time.sleep(2)
soup1 = BeautifulSoup(browser.page_source,'html.parser')
try :
    name_div_com = soup1.find('div',{'class':'ph5 pt3'})
    name_comp = name_div_com.find('span').get_text().strip()
    effic_ancien_list =soup1.find_all('span',{'class':'t-24 v-align-middle'})
    leplus = soup1.find('span',{'class':'org-highlight-insights-module__rate-increase'})
    if leplus==None:
        effic = "-"+effic_ancien_list[0].get_text().strip().replace('\xa0','')
    else :
        effic = effic_ancien_list[0].get_text().strip().replace('\xa0','')
    ancient = effic_ancien_list[1].get_text().strip().replace('\xa0','')
except Exception :
    print('NaN')

# %%
skillsection = soup.find('section', {'class','pv-profile-section pv-skill-categories-section artdeco-card mt4 p5 ember-view'})

# %%
skillslist = skillsection.find_all('span',{'class': 'pv-skill-category-entity__name-text t-16 t-black t-bold'})
for i in  range(len(skillslist)):
    print( skillslist[i].get_text().strip())
# Out:
# Python
# Machine Learning
# Analytical Skills

# %%
filename = 'test.csv'
f = open(filename,"w")
headers = ('name , skill1, skill2, skill3\n')
f.write(headers)
f.write(name+","+ skillslist[0].get_text().strip()+","+skillslist[1].get_text().strip()+","+skillslist[2].get_text().strip()+"\n")
f.write(name+","+ skillslist[0].get_text().strip()+","+skillslist[1].get_text().strip()+","+skillslist[2].get_text().strip()+"\n")
f.write(name+","+ skillslist[0].get_text().strip()+","+skillslist[1].get_text().strip()+","+skillslist[2].get_text().strip()+"\n")
f.close()

# %%
listtest = ['https://www.linkedin.com/in/zaid-hammouch-b81872a2',
            'https://www.linkedin.com/in/lamiaskalli',
 'https://www.linkedin.com/in/sarah-amar']

# %%
#open the file
filename = 'test4.csv'
f = open(filename,"w")
headers = ('name, location, skill1, skill2, skill3, name of the company ,Total headcount growth , Median tenure\n')
f.write(headers)

for link in reseachlinks:
    browser.get(link)
    time.sleep(10)
    browser.execute_script("window.scrollBy(0,1000)","")
    browser.execute_script("window.scrollBy(0,1500)","")
    time.sleep(10)
    sourcepg = browser.page_source
    soup = BeautifulSoup(sourcepg,'lxml')
    name_div = soup.find('div',{'class':"flex-1 mr5 pv-top-card__list-container"})
    ### find the name and the location and the 3 skills if the person
    name = name_div.find('li',{'class':"inline t-24 t-black t-normal break-words"}).get_text().strip()
    location = name_div.find('li',{'class':"t-16 t-black t-normal inline-block"}).get_text().strip().replace(',','')
    skillsection = soup.find('section', {'class','pv-profile-section pv-skill-categories-section artdeco-card mt4 p5 ember-view'})
    skillslist = skillsection.find_all('span',{'class': 'pv-skill-category-entity__name-text t-16 t-black t-bold'})
    skill1 = skillslist[0].get_text().strip()
    skill2 = skillslist[1].get_text().strip()
    skill3 = skillslist[2].get_text().strip()
    
    ### Find the url of the company
    exper_div= soup.find('div',{'class':"display-flex justify-space-between full-width"})
    exper_h3= exper_div.find_all('a',href = True)
    urltest = baseurl +exper_h3[0]['href']
    browser.get(urltest)
    scrollpg(2)
    time.sleep(2)
    soup1 = BeautifulSoup(browser.page_source,'html.parser')
    try :
        name_div_com = soup1.find('div',{'class':'ph5 pt3'})
        name_comp = name_div_com.find('span').get_text().strip()
        effic_ancien_list =soup1.find_all('span',{'class':'t-24 v-align-middle'})
        ### check if it's increase or decrease
        leplus = soup1.find('span',{'class':'org-highlight-insights-module__rate-increase'})
        if leplus==None:
            effic = "-"+effic_ancien_list[0].get_text().strip().replace('\xa0','')
        else :
            effic = effic_ancien_list[0].get_text().strip().replace('\xa0','')
        ancient = effic_ancien_list[1].get_text().strip().replace('\xa0','')
    except Exception :
        effic = "None"
        ancient= "None"
    f.write(name+","+ location+","+skill1+","+skill2+","+skill3+"," +name_comp+","+effic+","+ancient+"\n")
    print(name+","+ location+","+skill1+"|"+skill2+"|"+skill3+"|" +name_comp+" |"+effic+" | "+ancient+"\n")
        
        
f.close()
# Out:
# Zaid Hammouch,Morocco,Analyse de données|Python|Visualisation de données|Observatoire Marocain de la TPME |None | None
#
# Sarah Amar,Casablanca-Settat Morocco,Python|Machine Learning|Analytical Skills|Boston Consulting Group (BCG) |5% | 2.8 years
#
# Lamia Skalli,Morocco,Statistics|Algorithms|Data Science|AKUMEN IA (Valyans & AIOX Labs JV) |None | None
#
# fatima ezzahra banouj,Morocco,SPSS|Analyse de données|Statistique descriptives|Attijariwafa bank |2% | 5.7 years
#
# Hanane TRIY,Casablanca-Settat Morocco,Project Management|Operation research|Python|OCP S.A |4% | 5.9 years
#
# Ayoub Jannani,Morocco,Java|Machine Learning|Hadoop|OCP S.A |None | None
#
# Hajar Falih,Morocco,Machine Learning|Business Intelligence|Agile Methodologies|OCP S.A |4% | 5.9 years
#
# Siham eddamiri,Drâa-Tafilalet Morocco,Natural Language Processing (NLP)|Deep Learning|Semantic Web|USMBA - Université Sidi Mohamed Ben Abdellah - Fès - |13% | 6 years
#
# ...

# %%
#open the file
filename = 'test.csv'
f = open(filename,"w")
headers = ('name, location, skill1, skill2, skill3, name of the company ,Total headcount growth , Median tenure\n')
f.write(headers)

for link in reseachlinks:
    browser.get(link)
    time.sleep(10)
    browser.execute_script("window.scrollBy(0,1200)","")
    print("sqdqsd")
    browser.execute_script("window.scrollBy(0,1500)","")
    time.sleep(10)
    sourcepg = browser.page_source
    soup = BeautifulSoup(sourcepg,'html.parser')
    name_div = soup.find('div',{'class':"flex-1 mr5 pv-top-card__list-container"})
    ### find the name and the location and the 3 skills if the person
    name = name_div.find('li',{'class':"inline t-24 t-black t-normal break-words"}).get_text().strip()
    location = name_div.find('li',{'class':"t-16 t-black t-normal inline-block"}).get_text().strip
    skillsection = soup.find('section', {'class','pv-profile-section pv-skill-categories-section artdeco-card mt4 p5 ember-view'})
    print(skillsection)
f.close()
# Out:
# sqdqsd
# <section class="pv-profile-section pv-skill-categories-section artdeco-card mt4 p5 ember-view" id="ember333"><div class="display-flex">
# <h2 class="pv-profile-section__card-heading">
#     Skills &amp; endorsements
#   </h2>
# <!-- --></div>
# <!-- -->
# <!-- -->
# <ol class="pv-skill-categories-section__top-skills pv-profile-section__section-info section-info pb1">
# <li class="pv-skill-category-entity__top-skill pv-skill-category-entity pb3 pt4 pv-skill-endorsedSkill-entity relative ember-view" id="ember334">
# <div class="pv-skill-category-entity__skill-wrapper" tabindex="-1">
# <!-- -->
# <div class="display-flex align-items-center flex-grow-1 full-width">
# <p class="pv-skill-category-entity__name tooltip-container" tabindex="-1">
# ...

# %%
testlinks=['https://www.linkedin.com/in/zaid-hammouch-b81872a2?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAABXXSxEBA-q9ZRvXr-KKx_qd_o8RGyzZK7Q',
 'https://www.linkedin.com/in/sarah-amar?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAABs9j40BtZNMuP2QpB3UOQ_fH0FqYo7YaNE',
 'https://www.linkedin.com/in/lamiaskalli?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAACWLktUBrnX4odQldgO-duzvHonFYwG9W5s',
 'https://www.linkedin.com/in/fatima-ezzahra-banouj-00322257?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAv094MBp5lFoNuGhkUW1xhRWw9O3hCyWFU',
 'https://www.linkedin.com/in/hajar-falih-71661a3a?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAhHQIIBc9m72DBwbz0RUq5GK5ZcQ5h6Z5E',
 'https://www.linkedin.com/in/hamza-benjemra-36b848173?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAACk8zAMBC176js3ORY3txd1Ma67FzmNZLF4',
 'https://www.linkedin.com/in/mehdi-el-haylali?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAACPtp2sBeCms3Xkzu9XPX5Avqfqv28aR-og',
 'https://www.linkedin.com/in/siham-eddamiri-56b98aab?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAABd1qqMBXR-8N5zM7XmsnSWZINuidixon3U',
 'https://www.linkedin.com/in/azmi-mohamed-6051b91b?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAA